# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitfauzdar/AIML_Hands_on/blob/main/Ridge_%26_Lasso_Regression_Bangalore_House_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Business Problem - Predict the Price of Bangalore House
# Using Linear Regression - Supervised Machine Learning Algorithm

# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load Data

# %%
path = r"https://drive.google.com/uc?export=download&id=1xxDtrZKfuWQfl-6KA9XEd_eatitNPnkB"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0  150.0          1672.0    3     8971.291866
# 1   3.0      3.0  149.0          1750.0    3     8514.285714
# 2   3.0      2.0  150.0          1750.0    3     8571.428571
# 3   2.0      2.0   40.0          1250.0    2     3200.000000
# 4   2.0      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %% [markdown]
# ### Split Data

# %%
X = df.drop('price', axis=1)
y = df['price']

print('Shape of X = ', X.shape)
print('Shape of y = ', y.shape)
# Out:
# Shape of X =  (7120, 107)
# Shape of y =  (7120,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)

print('Shape of X_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of X_train =  (5696, 107)
# Shape of y_train =  (5696,)
# Shape of X_test =  (1424, 107)
# Shape of y_test =  (1424,)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Linear Regression - ML Model Training

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-5.70206143e+00, -1.25679916e+00,  8.27341833e+01, -1.44906911e+01,
#         5.75662723e+01,  1.88468905e-01, -1.72593897e+00, -4.51058311e+00,
#        -2.22589244e+00, -4.28978455e+00, -2.44590976e+00,  5.40246226e-01,
#        -1.03633400e+00,  1.43064873e+00, -6.25029424e-02, -1.51548783e+00,
#        -2.14422789e-01,  2.16244155e+00, -1.48710228e+00,  1.95250816e+00,
#        -3.10761125e+00, -1.28138668e+00, -1.01367155e+00,  1.37968545e-02,
#         1.10383858e+00,  1.26497611e+00, -3.52405517e+00, -1.21398741e+00,
#        -5.04622019e-01,  1.46299181e+00, -5.50064233e-01, -8.46468162e-02,
#         6.84882188e-01, -1.39849820e+00, -1.94761710e-02, -1.57716300e+00,
#         4.20886278e-01,  8.03443207e-01,  2.99182164e+00,  3.86430413e-03,
#         1.05037261e-01,  2.89115612e-01, -3.16916626e-01,  1.05625868e+00,
#        -1.39649279e+00, -3.10533604e+00,  1.01764011e-01, -7.49672917e-02,
# ...

# %%
lr.intercept_
# Out:
# np.float64(95.0802729985955)

# %% [markdown]
# ## Predict the value of Home and Test

# %%
X_test[0, :]
# Out:
# array([ 0.71301986,  0.0112734 ,  0.30202307,  0.65677518, -0.48064341,
#        -1.7385623 ,  2.11587407, -0.25430867,  0.51007548, -0.18373025,
#        -0.16389438, -0.1473229 , -0.13023539, -0.12812824, -0.12598816,
#        -0.12454231, -0.12953656, -0.12381344, -0.12010681, -0.11551113,
#        -0.10992018, -0.10909925, -0.10660036, -0.11234866, -0.09315135,
#        -0.08618799, -0.08923672, -0.09023078, -0.08721571, -0.09023078,
#        -0.08721571, -0.08195215, -0.08195215, -0.07633675, -0.0751646 ,
#        -0.08085949, -0.0739743 , -0.07975227, -0.07153563, -0.0751646 ,
#        -0.0677166 , -0.08085949, -0.07153563, -0.07862985, -0.0751646 ,
#        -0.07862985, -0.06504853, -0.0751646 , -0.06901264, -0.0751646 ,
#        -0.06901264, -0.07028523, -0.07276497, -0.07028523, -0.06367332,
#        -0.06226825, -0.06226825, -0.06639573, -0.06504853, -0.05935999,
#        -0.06083125, -0.06639573, -0.06639573, -0.06226825, -0.06367332,
# ...

# %%
lr.predict([X_test[0, :]])
# Out:
# array([76.90661876])

# %%
y_pred = pd.DataFrame(lr.predict(X_test))
y_pred
# Out:
#                0
# 0      76.906619
# 1      15.250054
# 2     113.682817
# 3      84.971203
# 4      18.861954
# ...          ...
# 1419   11.349984
# 1420   59.926348
# 1421   21.302969
# 1422   71.434630
# 1423  230.041463
#
# [1424 rows x 1 columns]

# %%
y_test
# Out:
# 2435     80.00
# 3113     40.00
# 426     120.00
# 1124     79.00
# 1161     45.00
#          ...
# 2078     28.34
# 6855     84.00
# 4381     32.00
# 3862     63.00
# 43      180.00
# Name: price, Length: 1424, dtype: float64

# %%
lr.score(X_test, y_test)
# Out:
# 0.7903837092682251

# %% [markdown]
# # Implementing Ridge and Lasso Regression
#
#
# ---
#
#
# ## Ridge Regression (L2 Regularization)
#
# Ridge Regression adds an L2 penalty (square of coefficients) to the loss function:
#
# Loss=
# MSE
# +
# 𝛼
# ∑
# 𝑤
# 2
# Loss=MSE+α∑w
# 2
#
# It reduces the magnitude of coefficients but does not make them exactly zero. Ridge regression is especially effective in handling multicollinearity and improving model stability.
#
#
# ---
#
#
#
#
# ## Lasso Regression (L1 Regularization)
#
# Lasso Regression adds an L1 penalty (absolute value of coefficients):
#
# Loss=
# MSE
# +
# 𝛼
# ∑
# ∣
# 𝑤
# ∣
# Loss=MSE+α∑∣w∣
#
# This penalty can shrink some coefficients to exactly zero, effectively performing feature selection. Lasso produces sparse models by retaining only the most important features.

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
rd = Ridge()

rd.fit(X_train,y_train)

rd.score(X_test, y_test)
# Out:
# 0.7905686374336628

# %%
ls = Lasso()

ls.fit(X_train,y_train)

ls.score(X_test, y_test)
# Out:
# 0.8036373003525774

# %%
rd2 = Ridge(alpha = 2)

rd2.fit(X_train,y_train)

rd2.score(X_test, y_test)
# Out:
# 0.7907530260397942

# %%
ls2 = Lasso(alpha=2)

ls2.fit(X_train,y_train)

ls2.score(X_test, y_test)
# Out:
# 0.8160181533703601

# %%
ls3 = Lasso(alpha=3)

ls3.fit(X_train,y_train)

ls3.score(X_test, y_test)
# Out:
# 0.8263450613017426

# %% [markdown]
# # Model Evaluation - MSE, Rmse & R2-score

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print("Mean Sq error:" , mse)
# Out:
# Mean Sq error: 4211.80690582333

# %%
import numpy as np
rmse = np.sqrt(mse)
print("Root mean sq error: ", rmse)
# Out:
# Root mean sq error:  64.89843531105608

# %%
r2 = r2_score(y_test, y_pred)
print("R2 score: ", r2)
# Out:
# R2 score:  0.7903837092682251
