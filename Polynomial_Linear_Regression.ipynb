# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitfauzdar/AIML_Hands_on/blob/main/Polynomial_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn import datasets

# %%
path = r"https://drive.google.com/uc?export=download&id=1xxDtrZKfuWQfl-6KA9XEd_eatitNPnkB"
df = pd.read_csv(path)
df.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0  150.0          1672.0    3     8971.291866
# 1   3.0      3.0  149.0          1750.0    3     8514.285714
# 2   3.0      2.0  150.0          1750.0    3     8571.428571
# 3   2.0      2.0   40.0          1250.0    2     3200.000000
# 4   2.0      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %% [markdown]
# # Split data

# %%
X = df.drop("price",axis = 1)
Y = df["price"]
X.shape , Y.shape
# Out:
# ((7120, 107), (7120,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, shuffle = True, random_state= 42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5696, 107), (1424, 107), (5696,), (1424,))

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.fit_transform(X_test)

# %%
X_train_scale
# Out:
# array([[-0.44422611,  0.54630035,  0.07232582, ..., -0.04782807,
#         -0.05138463, -0.04782807],
#        [ 0.6879045 ,  1.83462341,  0.17729421, ..., -0.04782807,
#         -0.05138463, -0.04782807],
#        [-0.44422611, -0.74202271, -0.50500027, ..., -0.04782807,
#         -0.05138463, -0.04782807],
#        ...,
#        [-0.44422611,  0.54630035, -0.35279612, ..., -0.04782807,
#         -0.05138463, -0.04782807],
#        [ 0.6879045 ,  0.54630035,  0.98030232, ..., -0.04782807,
#         -0.05138463, -0.04782807],
#        [-0.44422611,  0.54630035, -0.12186568, ..., -0.04782807,
#         -0.05138463, -0.04782807]])

# %%
X_test_scale
# Out:
# array([[-0.45268298,  0.58887587, -0.43419624, ..., -0.07028523,
#         -0.05935999, -0.07028523],
#        [-0.45268298,  0.58887587, -0.35013875, ..., -0.07028523,
#         -0.05935999, -0.07028523],
#        [-0.45268298, -0.74933961, -0.37454253, ..., -0.07028523,
#         -0.05935999, -0.07028523],
#        ...,
#        [-0.45268298,  0.58887587, -0.45453273, ..., -0.07028523,
#         -0.05935999, -0.07028523],
#        [-0.45268298, -0.74933961, -0.88973363, ..., -0.07028523,
#         -0.05935999, -0.07028523],
#        [-0.45268298, -0.74933961, -0.51825373, ..., -0.07028523,
#         -0.05935999, -0.07028523]])

# %%
# Polynomial Linear Regression - ML model Traing

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 2)
X_train_poly = poly.fit_transform(X_train_scale)
X_test_poly = poly.fit_transform(X_test_scale)

# %%
lr = LinearRegression()
lr.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train_poly,y_train)
# Out:
# 1.0

# %%
y_pred = lr.predict(X_test_poly)

# %%
y_test
# Out:
# 960      47.0
# 132      60.0
# 2431     65.0
# 2229    325.0
# 4503     60.0
#         ...
# 4970     48.0
# 553     205.0
# 1397     56.5
# 4056     26.0
# 1817     49.0
# Name: price, Length: 1424, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 95.98294565761185

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 456.0621911166839

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(21.3556126373533)
