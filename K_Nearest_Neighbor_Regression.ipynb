# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitfauzdar/AIML_Hands_on/blob/main/K_Nearest_Neighbor_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Business Problem - Predict the Price of Bangalore House
#
# **Using** K Nearest Neighbor Regression - Supervised Machine Learning Algorithm

# %%
# Load Libraries
import pandas as pd

# %%
# Load Data
path = r"https://drive.google.com/uc?export=download&id=1xxDtrZKfuWQfl-6KA9XEd_eatitNPnkB"
df = pd.read_csv(path)

df.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0  150.0          1672.0    3     8971.291866
# 1   3.0      3.0  149.0          1750.0    3     8514.285714
# 2   3.0      2.0  150.0          1750.0    3     8571.428571
# 3   2.0      2.0   40.0          1250.0    2     3200.000000
# 4   2.0      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
# Split Data
X = df.drop('price', axis=1)
y = df['price']

print('Shape of X = ', X.shape)
print('Shape of y = ', y.shape)
# Out:
# Shape of X =  (7120, 107)
# Shape of y =  (7120,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)

print('Shape of X_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of X_train =  (5696, 107)
# Shape of y_train =  (5696,)
# Shape of X_test =  (1424, 107)
# Shape of y_test =  (1424,)

# %% [markdown]
# ##K Nearest Neighbor Regression - ML Model Training

# %%
from sklearn.neighbors import KNeighborsRegressor

regressor = KNeighborsRegressor(n_neighbors=5)
regressor.fit(X_train, y_train)

regressor.score(X_test, y_test)
# Out:
# 0.8858214084886539

# %% [markdown]
# ## Predict the value of Home

# %%
X_test.iloc[-1, :]

regressor.predict([X_test.iloc[-1, :]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([184.4])

# %%
y_test.iloc[-1]

y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 77.378,  39.808, 120.2  , ...,  33.405,  63.   , 184.4  ])

# %%
y_test
# Out:
# 2435     80.00
# 3113     40.00
# 426     120.00
# 1124     79.00
# 1161     45.00
#          ...
# 2078     28.34
# 6855     84.00
# 4381     32.00
# 3862     63.00
# 43      180.00
# Name: price, Length: 1424, dtype: float64

# %%
regressor.score(X_test,y_test)
# Out:
# 0.8858214084886539

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
x_train_sc = sc.transform(X_train)
x_test_sc = sc.transform(X_test)

# %%
regressor.fit(x_train_sc, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = regressor.predict(x_test_sc)

# %%
regressor.score(x_test_sc,y_test)
# Out:
# 0.9112892295498807

# %% [markdown]
# ###This is wrong bcz:
#
#
# model always First argument → features (X)
#
# Second argument → true labels (y)

# %%
regressor.score(y_pred,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1531089738.py in <cell line: 0>()
# ----> 1 regressor.score(y_pred,y_test)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     660         from .metrics import r2_score
#     661
# --> 662         y_pred = self.predict(X)
#     663         return r2_score(y, y_pred, sample_weight=sample_weight)
#     664
#
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py in predict(self, X)
#     241             # In that case, we do not need the distances to perform
#     242             # the weighting so we do not compute them.
# --> 243             neigh_ind = self.kneighbors(X, return_distance=False)
#     244             neigh_dist = None
#     245         else:
#
# ...
